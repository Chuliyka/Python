# %% [markdown]
# # Списки, кортежі, словники, множини та виключення в Python
#
# ## Опис
#
# Ваше завдання — створити програму для мандрівника у часі, яка буде використовувати різні типи даних та обробку виключень у Python.
#
# ## Особливості
#
# - **Списки**: Вам потрібно створити список, кожен елемент якого буде кортежем із роком та подією в цьому році.
# - **Кортежі**: Кожен кортеж повинен містити рік та опис події.
# - **Словники**: Створіть словник, у якому ключі будуть роками, а значення — подіями.
# - **Множини**: Створіть множину років, які ви хочете відвідати.
# - **Виключення**: Ваш код повинен коректно обробляти ситуацію, коли зазначений рік відсутній у словнику часу.
#
# ## Завдання
#
# 1. Створіть список подій та словник часу, використовуючи списки та кортежі.
# 2. Ініціалізуйте множину років, які ви хочете відвідати.
# 3. Реалізуйте обробку виключень для років, яких немає в вашому словнику часу.
#
# ## Додаткове завдання
#
# Додайте функціональність, яка дозволяє користувачеві додавати та видаляти події із словника часу.
#
# <!-- image -->
# <div style="width: 100%; overflow: hidden; ">
# <img src="https://imgtr.ee/images/2023/10/02/979b09462432ad8113c07f8701ec17dc.jpeg" style="width: 90%; height: auto; margin-left: 5%;"/>
# </div>

# %%
french_events = [(843, "Верденський договір"),
           (1789, "Початок Французької революції"),
           (1791, "Прийняття першої Французької конституції"),
           (1804, "Коронація Наполеона Бонапарта на імператора Франції"),
           (1815, "Битва при Ватерлоо та загальний Конгрес у Відні"),
           (1830, "Липнева революція в Парижі"),
           (1848, "Французька революція 1848 року"),
           (1870, "Франко-пруська війна і заснування Третьої Республіки"),
           (1914, "Початок Першої світової війни"),
           (1940, "Падіння Франції перед нацистською Німеччиною"),
           (1944, "Визволення Франції під час Другої світової війни"),
           (1958, "Початок П'ятої Республіки і прихід до влади Карла Де Голля"),
           (1968, "Студентські та робітничі протести в Парижі"),
           (1992, "Підписання Маастрихтсього договору та створення Європейського Союзу"),
           (2019, "Початок жовтих жилетів, протестів проти реформ у Франції")]


time_check = {year: event for year, event in french_events}


years_to_visit = {843, 1789,1790,1830,1900,1914,1968,1992, 1984}


for year in years_to_visit:
    try:
        event = time_check[year]
        print(f"У {year} році сталася подія: {event}")
    except KeyError:
        print(f"У {year} році подія не відома")
# Out:
# У 1984 році подія не відома
# У 1830 році сталася подія: Липнева революція в Парижі
# У 1992 році сталася подія: Підписання Маастрихтсього договору та створення Європейського Союзу
# У 843 році сталася подія: Верденський договір
# У 1900 році подія не відома
# У 1968 році сталася подія: Студентські та робітничі протести в Парижі
# У 1914 році сталася подія: Початок Першої світової війни
# У 1789 році сталася подія: Початок Французької революції
# У 1790 році подія не відома
