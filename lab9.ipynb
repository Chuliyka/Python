# %% [markdown]
# # Лабораторна робота: Аналіз даних про втрати військової техніки та особового складу
#
# ## Мета:
# Вивчити базові прийоми аналізу даних за допомогою pandas та візуалізації даних з matplotlib на реальних даних.
#
# ## Завдання:
# 1. Попередня обробка даних.
# 2. Аналіз даних.
# 3. Візуалізація даних.
#
# ### Дані:
# - `russia_losses_equipment.csv` - дані про втрати техніки.
# - `russia_losses_equipment_correction.csv` - дані про корекції втрат техніки.
# - `russia_losses_personnel.csv` - дані про втрати особового складу.
#
# ### Попередня обробка даних:
# - Завантажте дані за допомогою pandas.
# - Очистіть дані від відсутніх значень та дублікатів.
# - Виконайте перетворення даних.
#
# ### Аналіз даних:
# - Розрахуйте основні статистичні показники.
# - Використайте групування для аналізу підгруп у даних.
# - Відсортуйте даних.
#
# ### Візуалізація даних:
# - Візуалізуйте дані за допомогою matplotlib.

# %%
    # Завантаження та попередня обробка даних
    import pandas as pd

    # Приклад завантаження даних
    # equipment_df = pd.read_csv('russia_losses_equipment.csv')
    # corrections_df = pd.read_csv('russia_losses_equipment_correction.csv')
    # personnel_df = pd.read_csv('russia_losses_personnel.csv')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\Ivanna\Downloads\lab9.ipynb Cell 2 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/Ivanna/Downloads/lab9.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> # Завантаження та попередня обробка даних
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Ivanna/Downloads/lab9.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> import pandas as pd
#       <a href='vscode-notebook-cell:/c%3A/Users/Ivanna/Downloads/lab9.ipynb#W1sZmlsZQ%3D%3D?line=3'>4</a> # Приклад завантаження даних
#       <a href='vscode-notebook-cell:/c%3A/Users/Ivanna/Downloads/lab9.ipynb#W1sZmlsZQ%3D%3D?line=4'>5</a> # equipment_df = pd.read_csv('russia_losses_equipment.csv')
#       <a href='vscode-notebook-cell:/c%3A/Users/Ivanna/Downloads/lab9.ipynb#W1sZmlsZQ%3D%3D?line=5'>6</a> # corrections_df = pd.read_csv('russia_losses_equipment_correction.csv')
#       <a href='vscode-notebook-cell:/c%3A/Users/Ivanna/Downloads/lab9.ipynb#W1sZmlsZQ%3D%3D?line=6'>7</a> # personnel_df = pd.read_csv('russia_losses_personnel.csv')
#
# ModuleNotFoundError: No module named 'pandas'

# %%
    # Аналіз даних
    # Приклад розрахунку основних статистичних показників
    # equipment_df.describe()

# %%
    # Візуалізація даних
    import matplotlib.pyplot as plt

    # Приклад візуалізації даних
    # plt.figure(figsize=(10,5))
    # plt.plot(equipment_df['date'], equipment_df['tanks'])
    # plt.xlabel('Дата')
    # plt.ylabel('Кількість втраченої техніки')
    # plt.title('Динаміка втрат танків')
    # plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from numpy import ceil


equipment_df = pd.read_csv('russia_losses_equipment.csv')
corrections_df = pd.read_csv('russia_losses_equipment_correction.csv')
personnel_df = pd.read_csv('russia_losses_personnel.csv')

print(equipment_df.head())

# %%
print(corrections_df.head())

# %%
print(personnel_df.head())

# %%
# очищення данних
#1equipment_df
clear_equipment_na = equipment_df.dropna()
clear_equipment_dubl = equipment_df.drop_duplicates()

print(clear_equipment_na)
print(clear_equipment_dubl)

# %%
#2corrections_df
clear_corrections_na = corrections_df.dropna()
clear_corrections_dubl = corrections_df.drop_duplicates()

print(clear_corrections_na)
print(clear_corrections_dubl)

# %%
#3personnel_df
clear_personnel_na = personnel_df.dropna()
clear_personnel_dubl = personnel_df.drop_duplicates()

print(clear_personnel_na)
print(clear_personnel_dubl)

# %%
# перетворення данних
average_value_equipment = equipment_df['tank'].mean()
average_value_equipment = ceil(average_value_equipment)
print(average_value_equipment)
# Out:
# 2861.0

# %%
average_value_corrections = corrections_df['helicopter'].mean()
average_value_corrections = ceil(average_value_corrections)
print(average_value_corrections)
# Out:
# 1.0

# %%
average_value_personnel  = personnel_df['personnel'].mean()
average_value_personnel  = ceil(average_value_personnel )
print(average_value_personnel)
# Out:
# 127875.0

# %%
# візуалізація данних 
plt.figure(figsize=(10,5))
plt.plot(equipment_df['date'], equipment_df['aircraft'])
plt.xlabel('Дата')
plt.ylabel('Кількість втраченої техніки')
plt.title('Динаміка втрат літаків')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(personnel_df['date'], personnel_df['personnel'])
plt.xlabel('Дата')
plt.ylabel('Кількість втраченого особового складу')
plt.title('Динаміка втрат особового складу')
plt.show()
