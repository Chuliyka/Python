# %% [markdown]
# ## Практичне завдання №1
#
# На основі вивченого матеріалу по темі "умовні конструкції" необхідно реалізувати наступну аплікацію.
#
# ### Аплікація
#
# Бізнес вимога: Замовник прийшов до вас із задачею - треба побудувати міні гру з варіативними виборами персонажа. Клієнт взагалі займається розробкою ігор, але їм зараз треба зробити швидко сценарій для невеличкої презентації, щоби показати загальний концепт і персонажів гри. Таким чином вони вирішили зробити невелику маркетингову компанію для клієнтів. За сценарієм клієнт, який попадає на сайт виробника має пройти невелику квест-гру, в якій він відповідатиме на запитання і по мірі проходження цих запитань він має досягати різних результатів гри. Має бути як мінімум 2-3 кінцівки.
#
# #### Деталі
#
# Користувачу мають задаватись питання один за одним. Питання, які будуть розвивати хід гри. Так, наприклад, гра має початися на першому рівні, на якому користувачу треба перемогти своїх ворогів.

# %%
import time
import random
# ця функція додасть інтерактиву в ваш чат і зробить його більш схожим на реальний.


def delay_print(s):
    for c in s:
        print(c, end='')
        time.sleep(random.random() * 0.01)
    print()

# %%
character_name = input("Вітаю! Введіть ім'я вашого персонажа.")
delay_print("Вітаю, " + character_name +
            "! Тобі належить вибрати свій шлях у невеликій грі, в результаті якої ти дізнаєшся який сік компанії Січко™ тобі підходить найбільше!")

# %%
# стати персонажа та ворогів
answers_array = []

# %%
# загальні дані про гілку діалогу
quest_index = 0

delay_print("Вітаю на першому рівні! До тебе підходить невідоме створіння, схоже на гнома, і каже:\n'Привіт, незнайомцю. Якщо ти хочеш пройти, то тобі потрібно відгадати загадку. Якщо ти не хочеш, то я тебе вб'ю.'")

print("Варіанти відповідей:\n1) 'Так, я хочу відгадати загадку.'\n2) 'Ні, я не хочу відгадувати загадку. (почати драку)'")

answer = input("Введіть відповідь: ")
answers_array.append(answer)

match answer:
    case "1": delay_print("Гном: 'Добре, тоді почнемо. Якщо ти відгадаєш, то я тобі дам піти.'")
    case "2": delay_print("Гном: 'Ти вирішив битися? Тоді почнемо.'")
    case _: delay_print("Гном: 'Я не розумію тебе. Якщо ти не зможеш відповісти, то я тебе вб'ю.'")


#Потрібно зробити піраміду з match case в одному блоці jupiter під загальним match case.

# %%
pre_answ = answers_array[0]

if (pre_answ == "1"):
    delay_print("Гном: 'У мами Івана було три сини. Першого звали Петро, другого – Василь. Як звали третього сина?'")
    print("Варіанти відповідей:\n 1 - Іван \n 2 - Василь \n 3 - Петро")
    answer = input("Відповідь: ")
    answers_array.append(answer)

    pre_answ = answers_array[1]

    if (pre_answ == "1"):
        delay_print("Молодець! Ходімо зі мною! \n Виберіть куди ви маєте піти \n 1 - АТБ \n 2 - Додому \n 3 - В село")
        answer = input("Відповідь: ")
        answers_array.append(answer)

        pre_answ = answers_array[2]

        if(pre_answ == "1"):
            print("Гном: Купи мені спагетті,курку,вершки і олію...")
        elif(pre_answ == "2"):
            print("Гном: Ось ти і попавня,друже,пора робити генеральне прибирання! =) ")
        elif(pre_answ == "3"):
            print("Гном: Сідаєш в 127 маршрутку,їдеш в село Кошелів і там тобі буде робота! ")
        else:
            quit() #Закінчити програму 



    elif(pre_answ == "2"):
        delay_print("Гном: Не правильно! Ось ще загадка. Що збільшується, але ніколи не зменшується?")
        print("Варіанти відповідей:\n 1 - Вік \n 2 - Пам'ять \n 3 - Волосся ")
        answer = input("Відповідь: ")
        answers_array.append(answer)

        pre_answ = answers_array[2]

        if(pre_answ == "1"):
            delay_print("Молодець! Ходімо зі мною! \n Виберіть куди ви маєте піти \n 1 - АТБ \n 2 - Додому \n 3 - В село")
            answer = input("Відповідь: ")
            answers_array.append(answer)

            pre_answ = answers_array[3]

            if(pre_answ == "1"):
                print("Гном: Купи мені спагетті,курку,вершки і олію...")
            elif(pre_answ == "2"):
                print("Гном: Ось ти і попавня,друже,пора робити генеральне прибирання! =) ")
            elif(pre_answ == "3"):
                print("Гном: Сідаєш в 127 маршрутку,їдеш в село Кошелів і там тобі буде робота! ")
            else:
                quit() #Закінчити програму

        elif(pre_answ == "2"):
            delay_print("Ні! Даю останній шанс! Які зуби у людини з'являються останніми? \n Варіанти відповіді: \n 1 - Штучні  \n 2 - зуб мудрості \n 3 - постійні ")
            answer = input("Відповідь: ")
            answers_array.append(answer)

            pre_answ = answers_array[3]

            if(pre_answ == "1"):
                delay_print("Молодець! Ходімо зі мною! \n Виберіть куди ви маєте піти \n 1 - АТБ \n 2 - Додому \n 3 - В село")
                answer = input("Відповідь: ")
                answers_array.append(answer)

                pre_answ = answers_array[4]

                if(pre_answ == "1"):
                    print("Гном: Купи мені спагетті,курку,вершки і олію...")
                elif(pre_answ == "2"):
                    print("Гном: Ось ти і попавня,друже,пора робити генеральне прибирання! =) ")
                elif(pre_answ == "3"):
                    print("Гном: Сідаєш в 127 маршрутку,їдеш в село Кошелів і там тобі буде робота! ")
                else:
                    quit() #Закінчити програму
            elif(pre_answ == "2"):
                print("Ви померли")
            elif(pre_answ == "3"):
                print("Ви померли")

    elif(pre_answ == "3"):
        delay_print("Гном: Не правильно! Ось ще загадка. Що збільшується, але ніколи не зменшується?")
        print("Варіанти відповідей:\n 1 - Вік \n 2 - Пам'ять \n 3 - Волосся ")
        answer = input("Відповідь: ")
        answers_array.append(answer)

        pre_answ = answers_array[2]

        if(pre_answ == "1"):
            delay_print("Молодець! Ходімо зі мною! \n Виберіть куди ви маєте піти \n 1 - АТБ \n 2 - Додому \n 3 - В село")
            answer = input("Відповідь: ")
            answers_array.append(answer)

            pre_answ = answers_array[3]

            if(pre_answ == "1"):
                print("Гном: Купи мені спагетті,курку,вершки і олію...")
            elif(pre_answ == "2"):
                print("Гном: Ось ти і попавня,друже,пора робити генеральне прибирання! =) ")
            elif(pre_answ == "3"):
                print("Гном: Сідаєш в 127 маршрутку,їдеш в село Кошелів і там тобі буде робота! ")
            else:
                quit() #Закінчити програму

        elif(pre_answ == "2"):
            delay_print("Ні! Даю останній шанс! Які зуби у людини з'являються останніми? \n Варіанти відповіді: \n 1 - Штучні  \n 2 - зуб мудрості \n 3 - постійні ")
            answer = input("Відповідь: ")
            answers_array.append(answer)

            pre_answ = answers_array[3]

            if(pre_answ == "1"):
                delay_print("Молодець! Ходімо зі мною! \n Виберіть куди ви маєте піти \n 1 - АТБ \n 2 - Додому \n 3 - В село")
                answer = input("Відповідь: ")
                answers_array.append(answer)

                pre_answ = answers_array[4]

                if(pre_answ == "1"):
                    print("Гном: Купи мені спагетті,курку,вершки і олію...")
                elif(pre_answ == "2"):
                    print("Гном: Ось ти і попавня,друже,пора робити генеральне прибирання! =) ")
                elif(pre_answ == "3"):
                    print("Гном: Сідаєш в 127 маршрутку,їдеш в село Кошелів і там тобі буде робота! ")
                else:
                    quit() #Закінчити програму
            elif(pre_answ == "2"):
                print("Ви померли")
            elif(pre_answ == "3"):
                print("Ви померли")


elif(pre_answ == "2"):
    delay_print("Ви почали битися з Гномом. Ви впали. Що зробите далі?")
    print("\n 1 - Окей. Вибач! Я відгадаю твої загадки \n 2 - Вдарити Гнома по голові з ноги.")

    answer = input("Відповідь: ")
    answers_array.append(answer)

    pre_answ = answers_array[1]

    if(pre_answ == "1"):

    
        delay_print("Гном: 'У мами Івана було три сини. Першого звали Петро, другого – Василь. Як звали третього сина?'")
        print("Варіанти відповідей:\n 1 - Іван \n 2 - Василь \n 3 - Петро")
        answer = input("Відповідь: ")
        answers_array.append(answer)

        pre_answ = answers_array[1]

        if (pre_answ == "1"):
            delay_print("Молодець! Ходімо зі мною! \n Виберіть куди ви маєте піти \n 1 - АТБ \n 2 - Додому \n 3 - В село")
            answer = input("Відповідь: ")
            answers_array.append(answer)

            pre_answ = answers_array[2]

            if(pre_answ == "1"):
                print("Гном: Купи мені спагетті,курку,вершки і олію...")
            elif(pre_answ == "2"):
                print("Гном: Ось ти і попавня,друже,пора робити генеральне прибирання! =) ")
            elif(pre_answ == "3"):
                print("Гном: Сідаєш в 127 маршрутку,їдеш в село Кошелів і там тобі буде робота! ")
            else:
                quit() #Закінчити програму 



        elif(pre_answ == "2"):
            delay_print("Гном: Не правильно! Ось ще загадка. Що збільшується, але ніколи не зменшується?")
            print("Варіанти відповідей:\n 1 - Вік \n 2 - Пам'ять \n 3 - Волосся ")
            answer = input("Відповідь: ")
            answers_array.append(answer)
    
            pre_answ = answers_array[2]
    
            if(pre_answ == "1"):
                delay_print("Молодець! Ходімо зі мною! \n Виберіть куди ви маєте піти \n 1 - АТБ \n 2 - Додому \n 3 - В село")
                answer = input("Відповідь: ")
                answers_array.append(answer)
    
                pre_answ = answers_array[3]
    
                if(pre_answ == "1"):
                    print("Гном: Купи мені спагетті,курку,вершки і олію...")
                elif(pre_answ == "2"):
                    print("Гном: Ось ти і попавня,друже,пора робити генеральне прибирання! =) ")
                elif(pre_answ == "3"):
                    print("Гном: Сідаєш в 127 маршрутку,їдеш в село Кошелів і там тобі буде робота! ")
                else:
                    quit() #Закінчити програму
    
            elif(pre_answ == "2"):
                delay_print("Ні! Даю останній шанс! Які зуби у людини з'являються останніми? \n Варіанти відповіді: \n 1 - Штучні  \n 2 - зуб мудрості \n 3 - постійні ")
                answer = input("Відповідь: ")
                answers_array.append(answer)
    
                pre_answ = answers_array[3]
    
                if(pre_answ == "1"):
                    delay_print("Молодець! Ходімо зі мною! \n Виберіть куди ви маєте піти \n 1 - АТБ \n 2 - Додому \n 3 - В село")
                    answer = input("Відповідь: ")
                    answers_array.append(answer)
    
                    pre_answ = answers_array[4]
    
                    if(pre_answ == "1"):
                        print("Гном: Купи мені спагетті,курку,вершки і олію...")
                    elif(pre_answ == "2"):
                        print("Гном: Ось ти і попавня,друже,пора робити генеральне прибирання! =) ")
                    elif(pre_answ == "3"):
                        print("Гном: Сідаєш в 127 маршрутку,їдеш в село Кошелів і там тобі буде робота! ")
                    else:
                        quit() #Закінчити програму
                elif(pre_answ == "2"):
                    print("Ви померли")
                elif(pre_answ == "3"):
                    print("Ви померли")
    
            elif(pre_answ == "3"):
                delay_print("Гном: Не правильно! Ось ще загадка. Що збільшується, але ніколи не зменшується?")
                print("Варіанти відповідей:\n 1 - Вік \n 2 - Пам'ять \n 3 - Волосся ")
                answer = input("Відповідь: ")
                answers_array.append(answer)

                pre_answ = answers_array[2]

                if(pre_answ == "1"):
                    delay_print("Молодець! Ходімо зі мною! \n Виберіть куди ви маєте піти \n 1 - АТБ \n 2 - Додому \n 3 - В село")
                    answer = input("Відповідь: ")
                    answers_array.append(answer)

                    pre_answ = answers_array[3]

                    if(pre_answ == "1"):
                        print("Гном: Купи мені спагетті,курку,вершки і олію...")
                    elif(pre_answ == "2"):
                        print("Гном: Ось ти і попавня,друже,пора робити генеральне прибирання! =) ")
                    elif(pre_answ == "3"):
                        print("Гном: Сідаєш в 127 маршрутку,їдеш в село Кошелів і там тобі буде робота! ")
                    else:
                        quit() #Закінчити програму

                elif(pre_answ == "2"):
                    delay_print("Ні! Даю останній шанс! Які зуби у людини з'являються останніми? \n Варіанти відповіді: \n 1 - Штучні  \n 2 - зуб мудрості \n 3 - постійні ")
                    answer = input("Відповідь: ")
                    answers_array.append(answer)
        
                    pre_answ = answers_array[3]
        
                    if(pre_answ == "1"):
                        delay_print("Молодець! Ходімо зі мною! \n Виберіть куди ви маєте піти \n 1 - АТБ \n 2 - Додому \n 3 - В село")
                        answer = input("Відповідь: ")
                        answers_array.append(answer)
        
                        pre_answ = answers_array[4]
        
                        if(pre_answ == "1"):
                            print("Гном: Купи мені спагетті,курку,вершки і олію...")
                        elif(pre_answ == "2"):
                            print("Гном: Ось ти і попавня,друже,пора робити генеральне прибирання! =) ")
                        elif(pre_answ == "3"):
                            print("Гном: Сідаєш в 127 маршрутку,їдеш в село Кошелів і там тобі буде робота! ")
                        else:
                            quit() #Закінчити програму
                    elif(pre_answ == "2"):
                        print("Ви померли")
                    elif(pre_answ == "3"):
                        print("Ви померли")
    
    else:
        delay_print("Ви дуже сильно вдарили гнома з ноги по голові і вбили його")
        print("Happy(maybe) end!!!")
